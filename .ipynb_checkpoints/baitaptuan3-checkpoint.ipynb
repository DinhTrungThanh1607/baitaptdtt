# %%
print(5&100)
# Out:
# 4

# %%
#W3A2
a,b=map(int,input().split())
a=a^b
b=a^b     #(a^b)^b=a^(b^b)=a^0=a
a=a^b     #a^(a^b)=(a^a)^b=0^b=b
print(f'a={a},b={b}')
# Out:
#  3 4
# a=4,b=3

# %%
#W3A4 cach 1
m,n=map(int,input().split())
print (int(m/n))
# Out:
#  3 4
# 0

# %%
#W3A4 cách 2
m,n=map(int,input().split())
print(m//n)
# Out:
#  5 2
# 2

# %%
#W3A4 cách 3
import math
m,n=map(int,input().split()) #Hàm math.floor() là hàm để làm tròng xuống
print(math.floor(m/n))
# Out:
#  5 2
# 2

# %%
#W3A5 cách 1
m,n=map(int,input().split())
print(int(m/n+1))
# Out:
#  5 2
# 3

# %%
#W3A5 cách 2
m,n=map(int,input().split())
print(m//n+1)
# Out:
#  5 2
# 3

# %%
#W3A5 cách 3
import math
m,n=map(int,input().split()) # hàm math.ceil() làm hàm để làm trong lên
print(math.ceil(m/n))
# Out:
#  5 2
# 3

# %%
m,n=map(int,input().split()) # sử dụng hàm round() để làm tròn đến số gần nhất
print(round(m/n))
# Out:
#  5 2
# 2

# %%
a,b,c,d=map(int,input().split())
q=b/a
if q.is_integer():
    if c==b*b/a and d==c*b/a:
        print("Đây là 1 cấp số nhân")
else:
    print("Đây không phải là cấp số nhân ")
# Out:
#  1 2 4 8
# Đây là 1 cấp số nhân
