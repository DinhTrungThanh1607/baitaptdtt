# %%
#Bai 1
a=float(input())
b=float(input())
print(a*b)
print(2*(a+b))
# Out:
#  3
#  4
# 12.0
# 14.0

# %%
#Bai2
r=float(input())
c=2*r*3.14
s=r**2*3.14
print(c,s)
# Out:
#  10
# 62.800000000000004 314.0

# %%
#Bai 3
import math
a=float(input())
b=float(input())
c=float(input())
if a>0 and b>0 and c>0 and a+b>c and a+c>b and b+c>a:
    chu_vi=a+b+c
    p=chu_vi/2
    dien_tich=math.sqrt(p*(p-a)*(p-b)*(p-c))
   
    if a==b==c:
        print("Day la tam giac deu")
    elif a==b or a==c or b==c:
        print("Day la tam giac can")
    elif a**2+b**2==c**2  or b**2+c**2==a**2 or a**2+c**2==b**2:
        print("Day la tam giac vuong")
   
    else:
        print("Day la tam giac thuong")
    print(f'Chu vi tam giac la: {chu_vi}')
    print(f'Dien tich tam giac la: {dien_tich}')
else:
    print("Day khong phai la tam giac")
# Out:
#  2
#  2
#  2
# Day la tam giac deu
# Chu vi tam giac la: 6.0
# Dien tich tam giac la: 1.7320508075688772

# %%
#Bai 4
a=float(input())
b=float(input())
print(f"Phuong trinh ax+b=0 co nghiem la x= {-b/a}")
# Out:
#  3
#  4
# Phuong trinh ax+b=0 co nghiem la x= -1.3333333333333333

# %%
#Bai 5
import math
a=float(input())
b=float(input())
c=float(input())
denta=b**2-4*a*c
if denta>0:
    x_1=(-b+ math.sqrt(denta))/(2*a)
    x_2=(-b- math.sqrt(denta))/(2*a)
    print(f'{"Phuong trinh co 2 nghiem phan biet x_1,x_2 la x_1="} {x_1}, {"x_2="} {x_2}')
elif denta==0:
    x=-b/(2*a)
    print(f'{"Phuong trinh co nghiem kep la x="} {x}')
else:
    print("Phuong trinh vo nghiem")
# Out:
#  1
#  5
#  -6
# Phuong trinh co 2 nghiem phan biet x_1,x_2 la x_1= 1.0, x_2= -6.0

# %%
#Bai 6
a, b, c, d= map(float, input().split())
max_value= max(a, b, c, d)
print(f"Gia tri lon nhat la {max_value}")
# Out:
#  1 2 3 4
# Gia tri lon nhat la 4.0

# %%
#Bai 7
a, b, c, d= map(float, input().split())
min_value=min(a, b, c, d)
print(f"Gia tri nho nhat la {min_value}")
# Out:
#  1 2 3 4
# Gia tri nho nhat la 1.0

# %%
#Bai 8
a,b,m,c,d,n=map(float, input().split())
det_A=a*d-b*c
det_x=m*d-n*b
det_y=a*n-c*m
if det_A!=0:
    print(f"He phuong trinh tuyen tinh nay co nghiem duy nhat la x;y={det_x/det_A};{det_y/det_A}")
elif det_A==det_x==det_y==0:
    print("He phuong trinh vo so nghiem")
else:
    print("He phuong trinh vo nghiem")
# Out:
#  0 2 6 0 3 3
# He phuong trinh vo nghiem

# %%
#Bai 9
x=int(input())
giay=x
phut=x/60
gio=x/3600
print(f"{giay} giay, {phut} phut, {gio} gio")
# Out:
#  345789
# 345789 giay, 5763.15 phut, 96.0525 gio

# %%
#Bai 10
#Tam cua duong tron la I(a;b), ban kinh la R, diem di qua la A(x;y)
a, b=map(float,input().split())
R=float(input())
x , y=map(float,input().split())
if (x-a)**2+(y-b)**2==R**2:
    print("Diem A co thuoc duong tron")
else:
    print("Diem A khong thuoc duong tron")
# Out:
#  0 0
#  5
#  5 0
# Diem A co thuoc duong tron

# %%
#Bai 11
x,y =map(float, input().split())
print(x**y)
print(pow(x,y))
# Out:
#  3 4
# 81.0
# 81.0
